# %%
import rosbag

# %%
bag = rosbag.Bag("../../../odom.bag")
for topic, msg, t in bag.read_messages(topics="/quadrotor_sim/Odometry"):
    print(msg.twist.twist.angular.z)
# Out:
# -0.722549100000006
# -0.778129800000008
# -0.8314785137401671
# -0.8733588727381801
# -0.905342212476263
# -0.9297673618685819
# -0.9484204455069639
# -0.9626654980155088
# -0.9735442098332024
# -0.9818521028809647
# -0.9881967036971672
# -0.9930419707478629
# -0.9967422213965521
# -0.999568041955648
# -1.0017183219030001
# -1.0032996889711252
# -1.00439077608875
# -1.0050688975379338
# -1.0054076867421267
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# -1.0054804561144555
# ...
